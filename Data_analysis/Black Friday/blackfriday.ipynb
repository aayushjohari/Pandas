# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv('BlackFriday.csv')

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
data.shape
# Out:
# (537577, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del data['Product_Category_2']
del data['Product_Category_3']

# %%
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data['User_ID'].nunique()
# Out:
# 5891

# %%
data['Product_ID'].nunique()
# Out:
# 3623

# %%
data['Product_ID'].value_counts()
# Out:
# Product_ID
# P00265242    1858
# P00110742    1591
# P00025442    1586
# P00112142    1539
# P00057642    1430
#              ...
# P00203242       1
# P00203642       1
# P00364342       1
# P00051742       1
# P00091742       1
# Name: count, Length: 3623, dtype: int64

# %%
for i in data.columns:
    print(i , ':' , data[i].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %%
data.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Purchase                      17959
# dtype: int64

# %%
data['Marital_Status'].nunique()
# Out:
# 2

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
data['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
data['Gender'].value_counts()
# Out:
# Gender
# M    405380
# F    132197
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64

# %%
data['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
data['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
data['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
data['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
data['Product_Category_1'].nunique()
# Out:
# 18

# %%
data['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %% [markdown]
# ## ANALYSE GENDER

# %%
sns.countplot(data['Gender'])
# Out:
# <Axes: xlabel='count', ylabel='Gender'>

# %%
plt.title('Gender analysis')
plt.pie(x = data['Gender'].value_counts() ,labels= data['Gender'].value_counts().index ,  autopct= '%.2f%%' ,  wedgeprops={'edgecolor' : "black"})
plt.legend()
plt.show()

# %%
plt.bar(x = data['Gender'].value_counts().index , height=data['Gender'].value_counts().values)
plt.title("Gender analysis")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
amountspend =data.groupby('Gender')['Purchase'].sum()

# %%
amountspend
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
plt.bar(amountspend.index , amountspend.values)
plt.show()

# %%
plt.pie(x = amountspend.values , autopct='%.2f%%' , labels =  amountspend.index)
plt.title("Amount spend by male and female")
plt.legend()
plt.show()

# %%
averageamount = data.groupby('Gender')['Purchase'].mean()

# %%
averageamount
# Out:
# Gender
# F    8809.761349
# M    9504.771713
# Name: Purchase, dtype: float64

# %%
plt.pie(x = averageamount.values , autopct='%.2f%%' , labels =  averageamount.index)
plt.title("Amount spend by per male and female")
plt.legend()
plt.show()

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
data.groupby('Gender')['Product_ID'].nunique()
# Out:
# Gender
# F    3358
# M    3582
# Name: Product_ID, dtype: int64

# %% [markdown]
# ## Age analysis

# %%
data.groupby('Age').size().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Age'>

# %%
data['Age'].value_counts()
# Out:
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64

# %%
sns.barplot(x = data['Age'].value_counts().values, y= data['Age'].value_counts().index )
# Out:
# <Axes: ylabel='Age'>

# %%
data['Age'].value_counts()
# Out:
# Age
# 26-35    214690
# 36-45    107499
# 18-25     97634
# 46-50     44526
# 51-55     37618
# 55+       20903
# 0-17      14707
# Name: count, dtype: int64

# %%
sns.countplot(data=data , x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
age = data.groupby('Age')['Product_ID'].nunique().reset_index()

# %%
sns.barplot(data=age , x = 'Age', y='Product_ID')
plt.show()

# %%
data.groupby('Age')['Purchase'].sum().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Age'>

# %%
data.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
data.groupby('Marital_Status').size().plot(kind='pie' , autopct = '%.2f%%')
# Out:
# <Axes: >

# %%
data['Marital_Status'].value_counts().plot(kind= 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x = 'Age' , hue = 'Gender' , data= data)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x = 'Gender' , hue = 'Age' , data= data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
sns.countplot(x = 'Gender' , hue = 'Marital_Status' , data= data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = data['City_Category'] , hue = 'Gender' , data= data)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x = data['City_Category'] , hue = 'Age' , data= data)
plt.legend(loc = 'center' , bbox_to_anchor=(0.5,0.8 ))

# %%
data['City_Category'].value_counts()
# Out:
# City_Category
# B    226493
# C    166446
# A    144638
# Name: count, dtype: int64

# %%
plt.pie(x = data['City_Category'].value_counts().values, autopct='%.2f%%' , labels=data['City_Category'].value_counts().index)
plt.show()

# %%
data.groupby('City_Category')['Purchase'].sum().plot(kind='pie' , autopct = '%.2f%%')
# Out:
# <Axes: ylabel='Purchase'>

# %%
data.groupby('City_Category')['Purchase'].mean().plot(kind='pie' , autopct = '%.2f%%')
# Out:
# <Axes: ylabel='Purchase'>

# %%
sns.countplot(x= data['Stay_In_Current_City_Years'] , hue = data['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
data.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
plt.pie(x =data['Stay_In_Current_City_Years'].value_counts() , autopct='%.2f'
        )
# Out:
# ([<matplotlib.patches.Wedge at 0x261f092b620>,
# ...
#  [Text(0.4934232283918172, 0.9831243653187509, ''),
#   Text(-1.0336548103929517, 0.37624158854585865, ''),
#   Text(-0.7839623304397539, -0.7716236546733584, ''),
#   Text(0.2576101628066115, -1.0694096521065963, ''),
#   Text(1.0021408719048066, -0.45355669199988047, '')],
#  [Text(0.26913994275917297, 0.5362496538102277, '35.19'),
#   Text(-0.5638117147597917, 0.2052226846613774, '18.50'),
#   Text(-0.4276158166035021, -0.4208856298218318, '17.36'),
#   Text(0.1405146342581517, -0.5833143556945071, '15.42'),
#   Text(0.546622293766258, -0.24739455927266202, '13.53')])

# %%
sns.countplot(data= data , x = 'Stay_In_Current_City_Years' , hue = 'Age')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data= data , x = 'Stay_In_Current_City_Years' , hue = 'Gender')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(data= data , x = 'Stay_In_Current_City_Years' , hue = 'Marital_Status')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
data.groupby('Stay_In_Current_City_Years')['Purchase'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=  data['Occupation'] , hue = data['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
data.groupby('Occupation')['Purchase'].sum().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(data = data , x = 'Occupation' , hue = 'Gender')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(data = data , x = 'Occupation' , hue = 'Marital_Status')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
plt.figure(figsize=(15,7))

sns.countplot(data = data , x = 'Occupation' , hue = 'Age')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>
